# %% [markdown]
# # Webscraping

# %%
#!mamba install pandas==1.3.3 -y
#!mamba install requests==2.26.0 -y
# !mamba install bs4==4.10.0 -y
# !mamba install html5lib==1.1 -y
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['bs4==4.10.0']
#
# pkgs/r/noarch            [<=>                 ] (00m:00s)
# pkgs/r/noarch            [=>                ] (00m:00s) 348 KB / ?? (1.12 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 348 KB / ?? (1.12 MB/s)
# pkgs/main/linux-64       [<=>                 ] (00m:00s)
# pkgs/r/noarch            [=>                ] (00m:00s) 348 KB / ?? (1.12 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 356 KB / ?? (1.14 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 348 KB / ?? (1.12 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 356 KB / ?? (1.14 MB/s)
# pkgs/main/noarch         [<=>                 ] (00m:00s)
# pkgs/r/noarch            [=>                ] (00m:00s) 348 KB / ?? (1.12 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 356 KB / ?? (1.14 MB/s)
# pkgs/main/noarch         [=>              ] (00m:00s) 232 KB / ?? (761.21 KB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 348 KB / ?? (1.12 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 356 KB / ?? (1.14 MB/s)
# pkgs/main/noarch         [=>              ] (00m:00s) 232 KB / ?? (761.21 KB/s)
# pkgs/r/linux-64          [<=>                 ] (00m:00s)
# pkgs/r/noarch            [=>                ] (00m:00s) 348 KB / ?? (1.12 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 356 KB / ?? (1.14 MB/s)
# pkgs/main/noarch         [=>              ] (00m:00s) 232 KB / ?? (761.21 KB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 352 KB / ?? (1.12 MB/s)
# pkgs/r/noarch            [<=>               ] (00m:00s) 348 KB / ?? (1.12 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 356 KB / ?? (1.14 MB/s)
# pkgs/main/noarch         [=>              ] (00m:00s) 232 KB / ?? (761.21 KB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 352 KB / ?? (1.12 MB/s)
# pkgs/r/noarch            [ <=>                ] (00m:00s) 1 MB / ?? (2.56 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 356 KB / ?? (1.14 MB/s)
# pkgs/main/noarch         [=>              ] (00m:00s) 232 KB / ?? (761.21 KB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 352 KB / ?? (1.12 MB/s)
# pkgs/r/noarch            [ <=>                ] (00m:00s) 1 MB / ?? (2.56 MB/s)
# pkgs/main/linux-64       [<=>               ] (00m:00s) 356 KB / ?? (1.14 MB/s)
# pkgs/main/noarch         [=>              ] (00m:00s) 232 KB / ?? (761.21 KB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 352 KB / ?? (1.12 MB/s)
# pkgs/r/noarch            [ <=>                ] (00m:00s) 1 MB / ?? (2.56 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [=>              ] (00m:00s) 232 KB / ?? (761.21 KB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 352 KB / ?? (1.12 MB/s)
# pkgs/r/noarch            [ <=>                ] (00m:00s) 1 MB / ?? (2.56 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>             ] (00m:00s) 232 KB / ?? (761.21 KB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 352 KB / ?? (1.12 MB/s)
# pkgs/r/noarch            [ <=>                ] (00m:00s) 1 MB / ?? (2.56 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 352 KB / ?? (1.12 MB/s)
# pkgs/r/noarch            [ <=>                ] (00m:00s) 1 MB / ?? (2.56 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/r/linux-64          [<=>               ] (00m:00s) 352 KB / ?? (1.12 MB/s)
# pkgs/r/noarch            [ <=>                ] (00m:00s) 1 MB / ?? (2.56 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) 1 MB / ?? (2.88 MB/s)
# pkgs/r/noarch            [ <=>                ] (00m:00s) 1 MB / ?? (2.56 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) Finalizing...
# pkgs/r/noarch            [ <=>                ] (00m:00s) 1 MB / ?? (2.56 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) Done
# pkgs/r/linux-64          [====================] (00m:00s) Done
# pkgs/r/noarch            [ <=>                ] (00m:00s) 1 MB / ?? (2.56 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/r/noarch            [ <=>                ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/r/noarch            [ <=>                ] (00m:00s) Done
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/r/noarch            [====================] (00m:00s) Done
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.79 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.17 MB/s)
# pkgs/main/noarch         [<=>               ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.17 MB/s)
# pkgs/main/noarch         [ <=>              ] (00m:00s) 644 KB / ?? (1.37 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.17 MB/s)
# pkgs/main/noarch         [ <=>              ] (00m:00s) 720 KB / ?? (1.11 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.17 MB/s)
# pkgs/main/noarch         [  <=>               ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.17 MB/s)
# pkgs/main/noarch         [  <=>               ] (00m:00s) Done
# pkgs/main/noarch         [====================] (00m:00s) Done
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.17 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 1 MB / ?? (2.17 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 2 MB / ?? (3.12 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 2 MB / ?? (3.12 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 3 MB / ?? (3.35 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 3 MB / ?? (3.35 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 4 MB / ?? (3.54 MB/s)
# pkgs/main/linux-64       [      <=>           ] (00m:00s) 4 MB / ?? (3.54 MB/s)
# pkgs/main/linux-64       [      <=>           ] (00m:00s) 5 MB / ?? (3.68 MB/s)
# pkgs/main/linux-64       [      <=>           ] (00m:01s) Finalizing...
# pkgs/main/linux-64       [      <=>           ] (00m:01s) Done
# pkgs/main/linux-64       [====================] (00m:01s) Done
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - bs4==4.10.0
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build           Channel                  Size
# ────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────
#
#   + bs4                  4.10.0  hd3eb1b0_0      pkgs/main/noarch        10 KB
#
#   Change:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - certifi           2022.9.24  pyhd8ed1ab_0    installed
#   + certifi           2022.9.24  py37h06a4308_0  pkgs/main/linux-64     154 KB
#   - openssl              1.1.1s  h0b41bf4_1      installed
#   + openssl              1.1.1s  h7f8727e_0      pkgs/main/linux-64       4 MB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates   2022.9.24  ha878542_0      installed
#   + ca-certificates  2022.10.11  h06a4308_0      pkgs/main/linux-64     124 KB
#
#   Downgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - beautifulsoup4       4.11.1  pyha770c72_0    installed
#   + beautifulsoup4       4.10.0  pyh06a4308_0    pkgs/main/noarch        85 KB
#
#   Summary:
#
#   Install: 1 packages
#   Change: 2 packages
#   Upgrade: 1 packages
#   Downgrade: 1 packages
#
#   Total download: 4 MB
#
# ────────────────────────────────────────────────────────────────────────────────
#
# Downloading  [>                                        ] (00m:00s)  314.37 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  314.37 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=>                                       ] (00m:00s) 1010.18 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished certifi                              (00m:00s)             154 KB   1009 KB/s
# Downloading  [=>                                       ] (00m:00s) 1010.18 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=>                                       ] (00m:00s) 1010.18 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=>                                       ] (00m:00s) 1010.18 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=>                                       ] (00m:00s) 1010.18 KB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [======================================>  ] (00m:00s)   20.22 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [======================================>  ] (00m:00s)   19.74 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Finished bs4                                  (00m:00s)              10 KB     53 KB/s
# Downloading  [======================================>  ] (00m:00s)   19.74 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [======================================>  ] (00m:00s)   19.74 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [======================================>  ] (00m:00s)   19.74 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [=======================================> ] (00m:00s)   19.97 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Finished openssl                              (00m:00s)               4 MB     19 MB/s
# Downloading  [=======================================> ] (00m:00s)   19.97 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [=======================================> ] (00m:00s)   19.97 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Finished ca-certificates                      (00m:00s)             124 KB    628 KB/s
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Finished beautifulsoup4                       (00m:00s)              85 KB    439 KB/s
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [========================>                ] (00m:00s)        3 / 5
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [========================>                ] (00m:00s)        3 / 5
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [================================>        ] (00m:00s)        4 / 5
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [================================>        ] (00m:00s)        4 / 5
# Downloading  [=========================================] (00m:00s)   19.88 MB/s
# Extracting   [=========================================] (00m:00s)        5 / 5
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['html5lib==1.1']
#
# pkgs/main/linux-64       Using cache
# pkgs/main/noarch         Using cache
# pkgs/r/linux-64          Using cache
# pkgs/r/noarch            Using cache
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - html5lib==1.1
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package         Version  Build         Channel                 Size
# ───────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────
#
#   + html5lib          1.1  pyhd3eb1b0_0  pkgs/main/noarch       91 KB
#   + webencodings    0.5.1  py37_1        pkgs/main/linux-64     19 KB
#
#   Summary:
#
#   Install: 2 packages
#
#   Total download: 110 KB
#
# ───────────────────────────────────────────────────────────────────────
#
# Downloading  [======>                                  ] (00m:00s)   74.01 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished webencodings                         (00m:00s)              19 KB     74 KB/s
# Downloading  [======>                                  ] (00m:00s)   74.01 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  422.76 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  422.76 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  422.76 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished html5lib                             (00m:00s)              91 KB    355 KB/s
# Downloading  [=========================================] (00m:00s)  422.76 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  422.76 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  422.76 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  422.76 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  422.76 KB/s
# Extracting   [=========================================] (00m:00s)        2 / 2
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from bs4 import BeautifulSoup
import html5lib
import requests
import pandas as pd

# %% [markdown]
# ## Extract Data Using Web Scraping

# %% [markdown]
# The wikipedia webpage [https://en.wikipedia.org/wiki/List_of_largest_banks](https://en.wikipedia.org/wiki/List_of_largest_banks?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) provides information about largest banks in the world by various parameters. Scrape the data from the table 'By market capitalization' and store it in a JSON file.

# %% [markdown]
# ### Webpage Contents
#
# Gather the contents of the webpage in text format using the `requests` library and assign it to the variable <code>html_data</code>

# %%
website = 'https://en.wikipedia.org/wiki/List_of_largest_banks?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01'
html_data = requests.get(website)

# %% [markdown]
# ### Scraping the Data
#
# Using the contents and `beautiful soup` load the data from the `By market capitalization` table into a `pandas` dataframe.

# %% [markdown]
# Using BeautifulSoup parse the contents of the webpage.

# %%
#Replace the dots below
soup = BeautifulSoup(html_data.content, "html.parser")

# %%
data = pd.DataFrame(columns=["Name", "Market Cap (US$ Billion)"])

for row in soup.find_all('tbody')[2].find_all('tr'):
    col = row.find_all('td')
    if col != []:
        bank_name = col[1].find_all('a')[1].text.strip()
        market_cap = col[2].text.strip()
        data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)

# %%
data.head()
# Out:
#                                       Name Market Cap (US$ Billion)
# 0                           JPMorgan Chase                   368.78
# 1  Industrial and Commercial Bank of China                   295.65
# 2                          Bank of America                   279.73
# 3                              Wells Fargo                   214.34
# 4                  China Construction Bank                   207.98

# %% [markdown]
# ### Loading the Data

# %%
data.to_json('bank_market_cap.json')

# %% [markdown]
# Copyright © 2020 IBM Corporation.
